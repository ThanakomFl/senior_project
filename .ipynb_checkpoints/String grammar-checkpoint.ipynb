# %%
import cv2
import matplotlib.pyplot as plt
import os
import imutils
import numpy as np
from skimage.feature import hog
import pdb

# %%
all_datalist = os.listdir('./dataset/have_2/')
mouth_cascade = cv2.CascadeClassifier('./src/mouth.xml')
ds_factor = 0.5

# %% [markdown]
# # Find average

# %%
fix_size_w = 150
fix_size_h = 75
dim = (fix_size_w, fix_size_h)

# %%
avg_f = []
for idx in range(len(all_datalist)):
    get_data = os.listdir('./dataset/have_2/'+all_datalist[idx]+'/train')
    for i in range(len(get_data)):
        cap = cv2.VideoCapture('./dataset/have_2/'+all_datalist[idx]+'/train/'+get_data[i])
        haveFrame,im = cap.read()
        avg_f_i = np.zeros((fix_size_h,fix_size_w))
        j = 0
        while(cap.isOpened()):
            print("pp : "+str(idx)+" Video : "+str(i)+" Frame : "+str(j))
            haveFrame,im = cap.read()
            if (not haveFrame) or (cv2.waitKey(1) & 0xFF == ord('q') or j > 50):
                break
            im = np.rot90(im)
            im = np.flipud(im)
            im = cv2.resize(im, None, fx=ds_factor, fy=ds_factor, interpolation=cv2.INTER_AREA)
            gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            mouth_rects = mouth_cascade.detectMultiScale(gray, 1.7, 11)
            for (x,y,w,h) in mouth_rects:
                y = int(y - 0.15*h)
                if(h > 100 and y > 400):
                    im = im[y:y+w,x:x+h]
                    break
            if(len(im) > 200):
                continue
            im = cv2.resize(im, dim, interpolation = cv2.INTER_AREA)
#             cv2.imwrite('./output/'+str(i)+"_"+str(j)+".jpg",im)
            im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            avg_f_i = avg_f_i + im
#             cv2.imshow('im', im)
#             cv2.moveWindow('im', 800, 50)
            j = j +1
        avg_f.append(avg_f_i/j) 
        cap.release()
        cv2.destroyAllWindows()
# Out:
# pp : 0 Video : 0 Frame : 0
# pp : 0 Video : 0 Frame : 1
# pp : 0 Video : 0 Frame : 2
# pp : 0 Video : 0 Frame : 3
# pp : 0 Video : 0 Frame : 4
# pp : 0 Video : 0 Frame : 5
# pp : 0 Video : 0 Frame : 6
# pp : 0 Video : 0 Frame : 7
# pp : 0 Video : 0 Frame : 8
# pp : 0 Video : 0 Frame : 9
# pp : 0 Video : 0 Frame : 10
# pp : 0 Video : 0 Frame : 11
# pp : 0 Video : 0 Frame : 12
# pp : 0 Video : 0 Frame : 13
# pp : 0 Video : 0 Frame : 14
# pp : 0 Video : 0 Frame : 15
# pp : 0 Video : 0 Frame : 16
# pp : 0 Video : 0 Frame : 17
# pp : 0 Video : 0 Frame : 18
# pp : 0 Video : 0 Frame : 19
# pp : 0 Video : 0 Frame : 20
# pp : 0 Video : 0 Frame : 21
# pp : 0 Video : 0 Frame : 22
# pp : 0 Video : 0 Frame : 23
# pp : 0 Video : 0 Frame : 24
# pp : 0 Video : 0 Frame : 25
# pp : 0 Video : 0 Frame : 26
# pp : 0 Video : 0 Frame : 27
# pp : 0 Video : 0 Frame : 28
# pp : 0 Video : 0 Frame : 29
# pp : 0 Video : 0 Frame : 30
# pp : 0 Video : 0 Frame : 31
# pp : 0 Video : 0 Frame : 32
# pp : 0 Video : 0 Frame : 33
for i in range(len(avg_f)):
    avg_f_ii = avg_f_ii + avg_f[i]
avg_f_ii = avg_f_ii / len(avg_f)

# %% [markdown]
# # Find Dif per Frame Train

# %%
true_label = []
stgm = []
for idx in range(len(all_datalist)):
    get_data = os.listdir('./dataset/have_2/'+all_datalist[idx]+'/train')
    for i in range(5,len(get_data)):
        cap = cv2.VideoCapture('./dataset/have_2/'+all_datalist[idx]+'/train/'+get_data[i])
        haveFrame,im = cap.read()
        j = 0
        avg_f_i = np.zeros((fix_size_h,fix_size_w))  
        stgm_i = []
        true_label_i = []
        while(cap.isOpened()):
            haveFrame,im = cap.read()
            print("pp : "+str(idx)+" Video : "+str(i)+" Frame : "+str(j))
            if (not haveFrame) or (cv2.waitKey(1) & 0xFF == ord('q') or j > 10):
                break
            im = np.rot90(im)
            im = np.flipud(im)
            im = cv2.resize(im, None, fx=ds_factor, fy=ds_factor, interpolation=cv2.INTER_AREA)
            gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            mouth_rects = mouth_cascade.detectMultiScale(gray, 1.7, 11)
            for (x,y,w,h) in mouth_rects:
                y = int(y - 0.15*h)
                if(h > 100 and y > 400):
                    im = im[y:y+w,x:x+h]
                    break
            if(len(im) > 200):
                continue
            im = cv2.resize(im, dim, interpolation = cv2.INTER_AREA)
            im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)    
            Dif_f = im-avg_f_ii
            Blur_f = cv2.GaussianBlur(im,(3,3),cv2.BORDER_DEFAULT,1)
            Fi_f = Dif_f / Blur_f
            fd, hog_image = hog(Fi_f, orientations=16, pixels_per_cell=(2,2),
                            cells_per_block=(2,2),visualize=True)
            stgm.append(fd)
            cv2.imshow('im_dif', Dif_f)
            cv2.moveWindow('im_dif', 800, 50)
            cv2.imshow('im_blur', Blur_f)
            cv2.moveWindow('im_blur', 1150,50)
            cv2.imshow('Fi_f', Fi_f)
            cv2.moveWindow('Fi_f', 450,50)
            cv2.imshow('Hog_img', hog_image)
            cv2.moveWindow('Hog_img', 100,50)
            cv2.imwrite('./output/'+str(i)+"_"+str(j)+".jpg",Fi_f*255)
            true_label.append(idx)
            j = j+1
        print('Get hog for 1 video')
        cap.release()
        cv2.destroyAllWindows()
# Out:
# pp : 0 Video : 5 Frame : 0
# pp : 0 Video : 5 Frame : 1
# pp : 0 Video : 5 Frame : 2
# pp : 0 Video : 5 Frame : 3
# pp : 0 Video : 5 Frame : 4
# pp : 0 Video : 5 Frame : 5
# pp : 0 Video : 5 Frame : 6
# pp : 0 Video : 5 Frame : 7
# pp : 0 Video : 5 Frame : 8
# pp : 0 Video : 5 Frame : 9
# pp : 0 Video : 5 Frame : 10
# pp : 0 Video : 5 Frame : 11
# Get hog for 1 video
# pp : 0 Video : 6 Frame : 0
# pp : 0 Video : 6 Frame : 1
# pp : 0 Video : 6 Frame : 2
# pp : 0 Video : 6 Frame : 3
# pp : 0 Video : 6 Frame : 4
# pp : 0 Video : 6 Frame : 5
# pp : 0 Video : 6 Frame : 6
# pp : 0 Video : 6 Frame : 7
# pp : 0 Video : 6 Frame : 8
# pp : 0 Video : 6 Frame : 9
# pp : 0 Video : 6 Frame : 10
# Get hog for 1 video
# pp : 2 Video : 11 Frame : 0
# pp : 2 Video : 11 Frame : 1
# pp : 2 Video : 11 Frame : 2
# pp : 2 Video : 11 Frame : 3
# pp : 2 Video : 11 Frame : 4
# pp : 2 Video : 11 Frame : 5
# pp : 2 Video : 11 Frame : 6
# pp : 2 Video : 11 Frame : 7
# pp : 2 Video : 11 Frame : 8
# pp : 2 Video : 11 Frame : 9
# pp : 2 Video : 11 Frame : 10
# pp : 2 Video : 11 Frame : 11
# Get hog for 1 video

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# X_train, X_test, y_train, y_test = train_test_split(stgm,true_label, test_size=0.33, random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(stgm,true_label)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %% [markdown]
# # Find Dif per Frame Test

# %%
true_label_test = []
stgm_test = []
for idx in range(len(all_datalist)):
    get_data = os.listdir('./dataset/have_2/'+all_datalist[idx]+'/test')
    for i in range(len(get_data)):
        cap = cv2.VideoCapture('./dataset/have_2/'+all_datalist[idx]+'/test/'+get_data[i])
        haveFrame,im = cap.read()
        j = 0
        avg_f_i = np.zeros((fix_size_h,fix_size_w))  
        stgm_i = []
        true_label_i = []
        while(cap.isOpened()):
            haveFrame,im = cap.read()
            if (not haveFrame) or (cv2.waitKey(1) & 0xFF == ord('q') or j > 10):
                break
            im = np.rot90(im)
            im = np.flipud(im)
            im = cv2.resize(im, None, fx=ds_factor, fy=ds_factor, interpolation=cv2.INTER_AREA)
            gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            mouth_rects = mouth_cascade.detectMultiScale(gray, 1.7, 11)
            for (x,y,w,h) in mouth_rects:
                y = int(y - 0.15*h)
                im = im[y:y+w,x:x+h]
                cv2.imshow('Hog_img', im)
                cv2.moveWindow('Hog_img', 100,50)
#                 if(h > 100 and y > 400 ):
#                     im = im[y:y+w,x:x+h]
#                     break

#             if(len(im) > 200):
#                 print('--------')
#                 continue
#             im = cv2.resize(im, dim, interpolation = cv2.INTER_AREA)
#             im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)    
#             Dif_f = im-avg_f_ii
#             Blur_f = cv2.GaussianBlur(im,(3,3),cv2.BORDER_DEFAULT,1)
#             Fi_f = Dif_f / Blur_f
#             fd, hog_image = hog(Fi_f, orientations=16, pixels_per_cell=(2,2),
#                             cells_per_block=(2,2),visualize=True)
#             cv2.imshow('im_dif', Dif_f)
#             cv2.moveWindow('im_dif', 800, 50)
#             cv2.imshow('im_blur', Blur_f)
#             cv2.moveWindow('im_blur', 1150,50)
#             cv2.imshow('Fi_f', Fi_f)
#             cv2.moveWindow('Fi_f', 450,50)
#             cv2.imshow('Hog_img', hog_image)
#             cv2.moveWindow('Hog_img', 100,50)
#             cv2.imwrite('./output/'+str(i)+"_"+str(j)+".jpg",Fi_f*255)
#             print("pp : "+str(idx)+" Video : "+str(i)+" Frame : "+str(j))
#             stgm_test.append(fd)
#             true_label_test.append(idx)
#             j = j+1
        print('Get hog for 1 video')
        cap.release()
        cv2.destroyAllWindows()
# Out:
# Get hog for 1 video
# Get hog for 1 video

# %%
y_pred = knn.predict(stgm_test)
accuracy_score(true_label_test, y_pred)

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(y_true, y_pred,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
plot_confusion_matrix(true_label_test, y_pred,
                      title='Face Classificaion ')
